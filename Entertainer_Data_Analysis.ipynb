# %%
#Importing libreries
import pandas as pd

# %%
# Importing Datasets
# Entertainer Basic Info
df_basic = pd.read_excel("Entertainer - Basic Info.xlsx")

# %%
# View the basic info data of Entertainers
df_basic.head(10)
# Out:
#        Entertainer Gender (traditional)  Birth Year Profession
# 0            Adele                    F        1988     Singer
# 1   Angelina Jolie                    F        1975      Actor
# 2  Aretha Franklin                    F        1942     Singer
# 3      Bette Davis                    F        1908      Actor
# 4      Betty White                    F        1922      Actor
# 5      Bing Crosby                    M        1903     Singer
# 6         Bob Hope                    M        1903      Actor
# 7    Carol Burnett                    F        1933      Actor
# 8   Carole Lombard                    F        1908      Actor
# 9    Carrie Fisher                    F        1956      Actor

# %%
# Import Entertainer_Breakthrough Info
df_breakthrough = pd.read_excel("Entertainer - Breakthrough Info.xlsx")

# %%
df_breakthrough.head(10)
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
# 5      Bing Crosby                                          1931
# 6         Bob Hope                                          1938
# 7    Carol Burnett                                          1959
# 8   Carole Lombard                                          1934
# 9    Carrie Fisher                                          1977
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
# Import Entertainer_Last work info
df_last_work_info = pd.read_excel("Entertainer - Last work Info.xlsx")

# %%
df_last_work_info.head(10)
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN
# 5      Bing Crosby                                1974         1977.0
# 6         Bob Hope                                1972         2003.0
# 7    Carol Burnett                                2016            NaN
# 8   Carole Lombard                                1942         1942.0
# 9    Carrie Fisher                                2016         2016.0

# %%
# Import Entertainer_Awards info
df_awards_info = pd.read_excel("Enterainer - Awards info.xlsx")

# %%
df_awards_info.head(10)
# Out:
#        Entertainer Profession Award Won from Breakthrough  Total Awards won  \
# 0            Adele     Singer                      Grammy                32
# 1   Angelina Jolie      Actor                       Oscar                58
# 2  Aretha Franklin     Singer                    No Award                29
# 3      Bette Davis      Actor                    No Award                34
# 4      Betty White      Actor                        Emmy                39
# 5      Bing Crosby     Singer                      Grammy                18
# 6         Bob Hope      Actor                    No Award                39
# 7    Carol Burnett      Actor                        Emmy                49
# 8   Carole Lombard      Actor                    No Award                 1
# 9    Carrie Fisher      Actor                       Other                 7
#
#    Total Nominees  Oscar Won  Grammy Won  Emmy Won  Other Awards
# 0              64          1          15         0             16
# ...
